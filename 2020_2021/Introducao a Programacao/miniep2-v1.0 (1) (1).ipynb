# %% [markdown]
# # MiniEP2 - MAC0110 - Introdução à Computação

# %% [markdown]
# NOME: insira seu nome
#
# NUSP: insira seu número USP

# %% [markdown]
# ## Parte 0 - Testes automatizados
#
# **NÃO ALTERE O CÓDIGO ABAIXO**
#
# Rode o trecho de código abaixo após terminar a tarefa para testar se
# suas funções estão funcionando como o esperado. Não é necessário
# entender o código abaixo :). Lembrando que, na correção, utilizaremos
# também testes adicionais.

# %%
function test()
    if soma2(0, 0) != 0 || soma2(-1, 1) != 0 || soma2(1, 2) != 3
        return "Erro. Verifique a função soma2"
    end
    if soma3(0, 0, 0) != 0 || soma3(1, 2, 3) != 6 || soma3(0, 50, -50) != 0
        return "Erro. Verifique a função soma3"
    end
    if calculaDelta(1, -10, 25) != 0 || calculaDelta(1, 3, -4) != 25 || calculaDelta(1, 1, 4) != -15
        return "Erro. Verifique a função calculaDelta"
    end
    
    return "Tudo OK :)"
end

print(test())

# %% [markdown]
# ## Parte 1 - Função soma2(x, y)
#
# Cria uma função _soma2_ que recebe os parâmetros _x_ e _y_, e devolve a soma dos dois parâmetros.

# %%
function soma2(a,b)
   println("Vou somar : ", a, " ", b)
    a = a + b
    print (a)
end

soma2(1,3)

# %% [markdown]
# ## Parte 2 - Função soma3(x, y, z)
#
# Crie uma função _soma3_ que recebe os parâmetros _x_, _y_, _z_ e devolve a soma dos três parâmetros. Você **DEVE** utilizar a função _soma2_ criada na _Parte 1_

# %%
function soma3(a,b,c)
   println("Vou somar : ", a, " ", b," ", c)
    a = a + b + c
    print (a)
end

soma3(1,3,4)

# %% [markdown]
# # Parte 3 - Função calculaDelta(a, b, c)
#
# Cria a função _calculaDelta_ que recebe os parâmetros _a_, _b_ e _c_ e devolve o _delta_.

# %%
function calculaDelta(a,b,c)
   println("Digite a, b e c : ", a, " ", b," ", c)
  b = b^2-4*a*c
    print (b)
end

calculaDelta(1,3,4)

# %% [markdown]
# ## Playground
#
# Utilize a área abaixo para testar suas funções, criar novas e brincar com a linguagem. Essa parte não será avaliada.

# %%
function calculaAreaPiramide(lado1,lado2,altura)
    base = 0
   println("digite o um lado da base, o outro e a altura : ",lado1, " ", lado2, " ",  altura)
  base = lado1* lado2
    area = 1/3 * (lado1*lado2)*altura
    print(area)
end

calculaAreaPiramide(1,3,99)
